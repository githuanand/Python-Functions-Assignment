# %% [markdown]
# 1. What is the difference between a function and a method in Python?

# %% [markdown]
# Function: A function is a block of reusable code defined using the def keyword. It can be called independently.
#
# Method: A method is a function associated with an object, typically called on an instance of a class. Methods implicitly take the instance (self) as the first parameter.
#
#
#
# ```
# # Function
# def greet(name):
#     return f"Hello, {name}!"
#
# print(greet("Alice"))  # Calling a function
#
# # Method
# class Greeter:
#     def greet(self, name):
#         return f"Hello, {name}!"
#
# greeter = Greeter()
# print(greeter.greet("Alice"))  # Calling a method
# ```

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.

# %% [markdown]
# Parameters: Variables listed in the function's definition.
#
# Arguments: Values passed to the function when it is called.
#
#
#
# ```
# # Parameters: 'a' and 'b'
# def add(a, b):
#     return a + b
#
# # Arguments: 5 and 3
# result = add(5, 3)
# print(result)  # Output: 8
# ```

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?

# %% [markdown]
# Define: Use the def keyword or lambda expressions.
#
# Call: Use the function name followed by parentheses containing arguments.
#
#
#
# ```
# # Defining a function
# def square(x):
#     return x * x
#
# # Calling a function
# print(square(4))  # Output: 16
#
# # Defining a lambda function
# cube = lambda x: x ** 3
#
# # Calling a lambda function
# print(cube(3))  # Output: 27
# ```

# %% [markdown]
# 4. What is the purpose of the return statement in a Python function?

# %% [markdown]
# The return statement is used to send a result back to the caller and terminate the function's execution.
#
#
# ```
# def multiply(a, b):
#     return a * b
#
# result = multiply(4, 5)
# print(result)  # Output: 20
# ```

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?

# %% [markdown]
# Iterables: Objects that can be looped over (e.g., lists, strings). They implement the __iter__ method.
#
# Iterators: Objects that represent a stream of data and implement the __next__ method. They are created from iterables using iter().
#
#
#
# ```
# iterable = [1, 2, 3]
# iterator = iter(iterable)  # Creating an iterator
#
# print(next(iterator))  # Output: 1
# print(next(iterator))  # Output: 2
# ```

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined.

# %% [markdown]
# Generators are a special type of iterator defined using a function with the yield keyword. They generate values on the fly and maintain their state.
#
#
#
# ```
# def count_up_to(n):
#     for i in range(1, n + 1):
#         yield i
#
# counter = count_up_to(3)
# print(next(counter))  # Output: 1
# print(next(counter))  # Output: 2
# ```

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?

# %% [markdown]
# *  Memory Efficiency: Generators produce items one at a time, reducing memory usage.
# *   Lazy Evaluation: Values are computed only when needed.
# *  Pipelining: Useful for handling large datasets.
#
# ```
# # Generator for large data
# def generate_numbers(n):
#     for i in range(n):
#         yield i
#
# for num in generate_numbers(1000000):  # No large memory allocation
#     if num > 5:
#         break
#     print(num)
# ```

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?

# %% [markdown]
# A lambda function is an anonymous function defined using the lambda keyword. It's typically used for short, simple functions.
#
#
#
# ```
# # Lambda function to add two numbers
# add = lambda a, b: a + b
# print(add(2, 3))  # Output: 5
#
# # Use in map function
# numbers = [1, 2, 3]
# squared = list(map(lambda x: x ** 2, numbers))
# print(squared)  # Output: [1, 4, 9]
# ```

# %% [markdown]
# 9. Explain the purpose and usage of the map() function in Python.

# %% [markdown]
# The map() function applies a given function to all the items in an iterable (like a list) and returns a map object (an iterator).
#
# ```
# # Doubling numbers in a list
# numbers = [1, 2, 3, 4]
# doubled = map(lambda x: x * 2, numbers)
# print(list(doubled))  # Output: [2, 4, 6, 8]
#
# ```

# %% [markdown]
# 10. What is the difference between map(), reduce(), and filter() functions in Python?

# %% [markdown]
# 1. map()
#
# 1.1 Purpose: Transforms each element of an iterable using a specified function.
#
# 1.2 Usage: It applies a function to every item and returns the modified result as an iterator.
#
# ```
# # Example:
# numbers = [1, 2, 3]
# doubled = map(lambda x: x * 2, numbers)
# print(list(doubled))  # Output: [2, 4, 6]
# ```
# 2. filter()
#
# 2.1 Purpose: Filters elements of an iterable based on a condition
# (function that returns True or False).
#
# 2.2 Usage: Only elements that satisfy the condition are returned.
#
# ```
# # Example:
# numbers = [1, 2, 3, 4]
# evens = filter(lambda x: x % 2 == 0, numbers)
# print(list(evens))  # Output: [2, 4]
# ```
#
# 3. reduce()
#
# 3.1. Purpose: Reduces an iterable to a single value by cumulatively applying a function.
#
# 3.2. Usage: It applies a binary function (function that takes two arguments) repeatedly.
#
# ```
# # Example:
# from functools import reduce
# numbers = [1, 2, 3, 4]
# sum_result = reduce(lambda x, y: x + y, numbers)
# print(sum_result)  # Output: 10
# ```

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:  [47,11,42,13]

# %% [markdown]
# **MECHANISM**

# %% [markdown]
# ![WhatsApp Image 2024-12-20 at 12.08.54_aa574506.jpg](data:image/jpeg;base64,...)

# %%
from functools import reduce

# List to sum
numbers = [47, 11, 42, 13]

# Using reduce
result = reduce(lambda x, y: x + y, numbers)
print(result)  # Output: 113
# Out:
# 113
